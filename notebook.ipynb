# %%
# %pip install ipympl
# %pip install interpolation
# %pip install pycbc
# %matplotlib ipympl
import matplotlib
matplotlib.use("module://ipympl.backend_nbagg")

import warnings
import logging
import os

# Suppress warnings
warnings.filterwarnings('ignore')

# Suppress other verbose output
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # If using TensorFlow
logging.getLogger().setLevel(logging.ERROR)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 25.0 -> 25.3
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 25.0 -> 25.3
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 25.0 -> 25.3
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # **Gravitational Wave Interactive Slider**

# %%
# %run main.py

# %% [markdown]
# The Gravitational Wave Slider is an educational tool that lets you explore how parameter estimation works in binary black hole mergers. Move the sliders to match the original signal and reference parameters and see how close you can get. The better the match, the more the waveform aligns with the data

# %% [markdown]
# ## **Parameters**
# * $m_{1}$: & Mass of the first black hole (in $M_\odot$)
# * $m_{2}$: & Mass of the second black hole (in $M_\odot$)
# * $\chi{1}$: & Dimensionless spin of the first black hole
# * $\chi_{2}$: & Dimensionless spin of the second black hole
#
# Quasinormal Parameters:
# * $\mathcal{M}$: Chirp mass of the system
# * $q$: Mass ratio of the system
# * $\chi_{+}$: Effective sin of the system
# * $\chi_{-}$: Precessional spin of the system
#
# Other Variables:
# * $Amplitude$: Strain amplitude
# * $Phase$: Phase at coalescence
# * $\rho$: Signal-to-Noise Ratio (SNR)

# %% [markdown]
# ## **Buttons**
#
# * **Reference Parameters:** Takes you to the published parameters for that waveform
# * **Use Real Data:** Lets you choose from several real gravitational wave signals
# * **Toggle Detectors:** Displays the signal from LIGO detectors in Hanford, Washington (H1) and Livingston, Louisiana (L1).
# * **Residuals:** Plots the residuals of the signal
